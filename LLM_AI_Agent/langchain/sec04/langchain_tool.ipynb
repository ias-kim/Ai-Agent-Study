# %%
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

load_dotenv()

model = ChatOpenAI(model="gpt-4o-mini")
for c in model.stream([HumanMessage("잘 지냈어? 한국 사회의 문제점이 무엇인지 이야기해줘")]):
    print(c.content, end='|')
# Out:
# /Users/gwan/Desktop/code/AI-Agent/LLM_AI_Agent/.venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# |안|녕하세요|!| 한국| 사회|의| 문제|점|은| 다양|하고| 복|잡|한|데|,| 몇| 가지| 주요|한| 주|제를| 들어|보|겠습니다|.
#
# |1|.| **|고|용| 불|안|정| 및| 청|년| 실|업|**|:| 한국|에서는| 청|년| 실|업|률|이| 높은| 편|입니다|.| 경쟁|이| 치|열|한| 취|업| 시장|과| 정|규|직| 채|용|의| 어려|움|은| 젊|은| 세|대|에게| 큰| 부담|을| 주|고| 있습니다|.
#
# |2|.| **|주|거| 문제|**|:| 서울|을| 비롯|한| 대|도|시|의| 집|값| 상승|으로| 인해| 많은| 사람들이| 주|거| 비용|에| 어려|움을| 겪|고| 있습니다|.| 이|로| 인해| 젊|은| 층|은| 독|립|적인| 생활|을| 하기| 어려|워|지고| 있습니다|.
#
# |3|.| **|저|출|산|과| 인|구| 고|령|화|**|:| 저|출|산| 문제|는| 한국| 사회|의| 큰| 위|기| 중| 하나|로|,| 이는| 경제| 성장|과| 사회| 복|지| 시스템|에| 심|각|한| 영향을| 미|칠| 수| 있습니다|.| 또한| 고|령|화|로| 인|한| 연|금| 및| 의료| 부담|도| 커|지고| 있습니다|.
#
# |4|.| **|성|별| 불|평|등|**|:| 한국|은| 성|별| 간|의| 임|금| 격|차|와| 사회|적| 역할|에| 대한| 고|정|관|념| 등| 성|불|평|등| 문제가| 여|전히| 존재|합니다|.| 여성|의| 경|력| 단|절|과| 남|녀| 간|의| 불|균|형|이| 사회|적| 논|란|이| 되|곤| 합니다|.
#
# |5|.| **|정|신| 건강| 문제|**|:| 한국| 사회|에서| 정신| 건강| 문제|에| 대한| 인|식|이| 부족|하며|,| 정신| 질|환|에| 대한| 낙|인이| 여|전히| 존재|합니다|.| 이|로| 인해| 많은| 사람들이| 도움|을| 요청|하기| 어려|운| 상황|입니다|.
#
# |6|.| **|사회|적| 양|극|화|**|:| 경제|적| 불|평|등|이| 심|화|되|면서| 사회|적| 양|극|화|가| 진행|되고| 있습니다|.| 이|로| 인해| 계|층| 간|의| 갈|등|과| 불|만|이| 커|지고| 있습니다|.
#
# |이| 외|에도| 환경| 문제|,| 교육|의| 경쟁| 과|열|,| 지역| 간| 격|차| 등| 여러| 가지| 이|슈|가| 있습니다|.| 이러한| 문제|들은| 상|호| 연결|되어| 있으며|,| 효과|적인| 해결|책|을| 찾|기| 위해|서는| 사회| 전|반|에| 걸|친| 접근|과| 협|력이| 필요|합니다|.||||

# %%
messages = [
    SystemMessage("너는 사용자의 질문에 답변을 하기 위해 tools를 사용할 수 있다."),
    HumanMessage("부산은 지금 몇 시야?"),
]

response = llm_with_tools.stream(messages)

is_first = True

for chunk in response:
    print("chunk type", type(chunk))

    if is_first:
        is_first = False
        gathered = chunk
    else:
        gathered += chunk

    print("content: ", gathered.content, "tool_call_chunk", gathered.tool_calls)

messages.append(gathered)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 messages = [
# ----> 2     SystemMessage("너는 사용자의 질문에 답변을 하기 위해 tools를 사용할 수 있다."),
#       3     HumanMessage("부산은 지금 몇 시야?"),
#       4 ]
#       6 response = llm_with_tools.stream(messages)
#       8 is_first = True
#
# NameError: name 'SystemMessage' is not defined
